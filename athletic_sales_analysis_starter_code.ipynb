# %%
# Import Libraries and Dependencies
import pandas as pd
from datetime import date

# %% [markdown]
# ### 1. Combine and Clean the Data
# #### Import CSVs

# %%
# Read the CSV files into DataFrames.
athletic_sales_2020 = pd.read_csv("Resources/athletic_sales_2020.csv") # read the files into a variables
athletic_sales_2021 = pd.read_csv("Resources/athletic_sales_2021.csv")
sales_2020 = pd.DataFrame(athletic_sales_2020) # converting the variables to a data frame
sales_2021 = pd.DataFrame(athletic_sales_2021)

# %%
# Display the 2020 sales DataFrame
display(sales_2020)
# Out:
#          retailer  retailer_id invoice_date     region         state  \
# 0     Foot Locker      1185732       1/1/20  Northeast      New York
# 1     Foot Locker      1185732       1/1/20  Northeast  Pennsylvania
# 2     Foot Locker      1185732       1/1/20  Northeast  Pennsylvania
# 3     Foot Locker      1185732       1/1/20  Northeast      New York
# 4     Foot Locker      1185732       1/1/20  Northeast  Pennsylvania
# ...           ...          ...          ...        ...           ...
# 1292    West Gear      1128299     12/30/20       West    California
# 1293    West Gear      1128299     12/30/20       West    California
# 1294       Kohl's      1189833     12/30/20    Midwest     Minnesota
# 1295       Kohl's      1189833     12/30/20    Midwest     Minnesota
# 1296    West Gear      1128299     12/30/20       West    California
#
#                city                  product  price_per_unit  units_sold  \
# ...

# %%
# Display the 2021 sales DataFrame
display(sales_2021)
# Out:
#          retailer  retailer_id invoice_date     region         state  \
# 0       West Gear      1128299       1/1/21       West    California
# 1       West Gear      1128299       1/1/21       West    California
# 2          Kohl's      1189833       1/1/21    Midwest       Montana
# 3          Kohl's      1189833       1/1/21    Midwest       Montana
# 4       West Gear      1128299       1/1/21       West    California
# ...           ...          ...          ...        ...           ...
# 8341  Foot Locker      1185732     12/31/21  Northeast  Pennsylvania
# 8342  Foot Locker      1185732     12/31/21  Northeast  Pennsylvania
# 8343       Amazon      1185732     12/31/21  Northeast         Maine
# 8344       Amazon      1185732     12/31/21  Northeast         Maine
# 8345  Foot Locker      1185732     12/31/21  Northeast  Pennsylvania
#
#                city                  product  price_per_unit  units_sold  \
# ...

# %% [markdown]
# #### Check the data types of each DataFrame

# %%
# Check the 2020 sales data types.
sales_2020.dtypes
# Out:
# retailer             object
# retailer_id           int64
# invoice_date         object
# region               object
# state                object
# city                 object
# product              object
# price_per_unit        int64
# units_sold            int64
# total_sales           int64
# operating_profit    float64
# sales_method         object
# dtype: object

# %%
# Check the 2021 sales data types.
sales_2021.dtypes
# Out:
# retailer             object
# retailer_id           int64
# invoice_date         object
# region               object
# state                object
# city                 object
# product              object
# price_per_unit        int64
# units_sold            int64
# total_sales           int64
# operating_profit    float64
# sales_method         object
# dtype: object

# %% [markdown]
# #### Combine the sales data by rows.

# %%
# Combine the 2020 and 2021 sales DataFrames on the rows and reset the index.
sales_2020_2021_df = pd.concat([sales_2020, sales_2021], axis='rows', join='inner')
sales_2020_2021_df = sales_2020_2021_df.reset_index(drop=True)
display(sales_2020_2021_df)
# Out:
#          retailer  retailer_id invoice_date     region         state  \
# 0     Foot Locker      1185732       1/1/20  Northeast      New York
# 1     Foot Locker      1185732       1/1/20  Northeast  Pennsylvania
# 2     Foot Locker      1185732       1/1/20  Northeast  Pennsylvania
# 3     Foot Locker      1185732       1/1/20  Northeast      New York
# 4     Foot Locker      1185732       1/1/20  Northeast  Pennsylvania
# ...           ...          ...          ...        ...           ...
# 9638  Foot Locker      1185732     12/31/21  Northeast  Pennsylvania
# 9639  Foot Locker      1185732     12/31/21  Northeast  Pennsylvania
# 9640       Amazon      1185732     12/31/21  Northeast         Maine
# 9641       Amazon      1185732     12/31/21  Northeast         Maine
# 9642  Foot Locker      1185732     12/31/21  Northeast  Pennsylvania
#
#               city                product  price_per_unit  units_sold  \
# ...

# %%
# Check if any values are null.
sales_2020_2021_df.isnull().sum()
# Out:
# retailer            0
# retailer_id         0
# invoice_date        0
# region              0
# state               0
# city                0
# product             0
# price_per_unit      0
# units_sold          0
# total_sales         0
# operating_profit    0
# sales_method        0
# dtype: int64

# %%
# Check the data type of each column
sales_2020_2021_df.dtypes
# Out:
# retailer             object
# retailer_id           int64
# invoice_date         object
# region               object
# state                object
# city                 object
# product              object
# price_per_unit        int64
# units_sold            int64
# total_sales           int64
# operating_profit    float64
# sales_method         object
# dtype: object

# %%
# Convert the "invoice_date" to a datetime datatype
# use format optio

# .to_datetime('2018-10-26 12:00:00.0000000011',
# ...                format='%Y-%m-%d %H:%M:%S.%f')
# sales_2020_2021_df['invoice_date'] = pd.to_datetime(sales_2020_2021_df['invoice_date'])
# sales_2020_2021_df['invoice_date'].to_datetime(['invoice_date'], format='%m/%d/%y', errors="coerce")
sales_2020_2021_df['invoice_date'] = pd.to_datetime(sales_2020_2021_df['invoice_date'], errors="coerce")
sales_2020_2021_df.head(20)
# Out:
#        retailer  retailer_id invoice_date     region         state  \
# 0   Foot Locker      1185732   2020-01-01  Northeast      New York
# 1   Foot Locker      1185732   2020-01-01  Northeast  Pennsylvania
# 2   Foot Locker      1185732   2020-01-01  Northeast  Pennsylvania
# 3   Foot Locker      1185732   2020-01-01  Northeast      New York
# 4   Foot Locker      1185732   2020-01-01  Northeast  Pennsylvania
# 5   Foot Locker      1185732   2020-01-01  Northeast      New York
# 6     West Gear      1128299   2020-01-02  Northeast  Pennsylvania
# 7     West Gear      1128299   2020-01-02  Northeast  Pennsylvania
# 8   Foot Locker      1185732   2020-01-02  Northeast      New York
# 9     West Gear      1128299   2020-01-02  Northeast  Pennsylvania
# 10  Foot Locker      1185732   2020-01-02  Northeast      New York
# 11  Foot Locker      1185732   2020-01-02  Northeast      New York
# 12    West Gear      1128299   2020-01-03  Northeast  Pennsylvania
# ...

# %%
# Confirm that the "invoice_date" data type has been changed.
sales_2020_2021_df.dtypes
# Out:
# retailer                    object
# retailer_id                  int64
# invoice_date        datetime64[ns]
# region                      object
# state                       object
# city                        object
# product                     object
# price_per_unit               int64
# units_sold                   int64
# total_sales                  int64
# operating_profit           float64
# sales_method                object
# dtype: object

# %% [markdown]
# ### 2. Determine which Region Sold the Most Products

# %% [markdown]
# #### Using `groupby`

# %%
# Show the number products sold for region, state, and city.
total_sold_products = sales_2020_2021_df.groupby(['region', 'state', 'city'])[['units_sold']].sum()
# Rename the sum to "Total_Products_Sold".
total_sold_products = total_sold_products.rename(columns={"units_sold":"Total_Products_Sold"})

# Show the top 5 results.
total_sold_products.sort_values(by=['Total_Products_Sold'], ascending=False).head()
# Out:
#                                     Total_Products_Sold
# region    state      city
# Northeast New York   New York                    111954
# South     Texas      Houston                      90322
# West      California San Francisco                85478
#                      Los Angeles                  76384
# Southeast Florida    Miami                        73135

# %% [markdown]
# #### Using `pivot_table`

# %%
# Show the number products sold for region, state, and city.
Total_Products_Sold = pd.pivot_table(sales_2020_2021_df, index=['region', 'state', 'city'], values=['units_sold'], aggfunc='sum', sort='descending')

# Rename the "units_sold" column to "Total_Products_Sold"
Total_Products_Sold = Total_Products_Sold.rename(columns={"units_sold":"Total_Products_Sold"})

# Show the top 5 results.
Total_Products_Sold.sort_values(by=['Total_Products_Sold'], ascending=False).head()
# Out:
#                                     Total_Products_Sold
# region    state      city
# Northeast New York   New York                    111954
# South     Texas      Houston                      90322
# West      California San Francisco                85478
#                      Los Angeles                  76384
# Southeast Florida    Miami                        73135

# %% [markdown]
# ### 3. Determine which Region had the Most Sales

# %% [markdown]
# #### Using `groupby`

# %%
# Show the total sales for the products sold for each region, state, and city.
total_sales_df = sales_2020_2021_df.groupby(['region', 'state', 'city'])[['total_sales']].sum()

# Rename the "total_sales" column to "Total Sales"
total_sales_df = total_sales_df.rename(columns={"total_sales":"Total Sales"})

# Show the top 5 results.
total_sales_df.sort_values(by=['Total Sales'], ascending=False).head()
# Out:
#                                         Total Sales
# region    state          city
# Northeast New York       New York          39801235
# West      California     San Francisco     33973228
# Southeast Florida        Miami             31600863
#           South Carolina Charleston        29285637
#           Florida        Orlando           27682851

# %% [markdown]
# #### Using `pivot_table`

# %%
# Show the total sales for the products sold for each region, state, and city.
sales_total_df = pd.pivot_table(sales_2020_2021_df, index=['region', 'state', 'city'], values=['total_sales'], aggfunc='sum', sort='descending')

# Optional: Rename the "total_sales" column to "Total Sales"
sales_total_df = sales_total_df.rename(columns={"total_sales":"Total Sales"})

# Show the top 5 results.
sales_total_df.sort_values(by=['Total Sales'], ascending=False).head()
# Out:
#                                         Total Sales
# region    state          city
# Northeast New York       New York          39801235
# West      California     San Francisco     33973228
# Southeast Florida        Miami             31600863
#           South Carolina Charleston        29285637
#           Florida        Orlando           27682851

# %% [markdown]
# ### 4. Determine which Retailer had the Most Sales

# %% [markdown]
# #### Using `groupby`

# %%
# Show the total sales for the products sold for each retailer, region, state, and city.
total_sales_retailer_df = sales_2020_2021_df.groupby(['retailer','region', 'state', 'city'])[['total_sales']].sum()

# Rename the "total_sales" column to "Total Sales"
total_sales_retailer_df = total_sales_retailer_df.rename(columns={"total_sales":"Total Sales"})

# Show the top 5 results.
total_sales_retailer_df.sort_values(by=['Total Sales'], ascending=False).head()
# Out:
#                                                     Total Sales
# retailer    region    state          city
# West Gear   West      California     San Francisco     32794405
# Kohl's      West      California     Los Angeles       25127160
# Foot Locker Northeast New York       New York          25008568
# West Gear   West      Washington     Seattle           24862675
# Foot Locker Southeast South Carolina Charleston        24822280

# %% [markdown]
# #### Using `pivot_table`

# %%
# Show the total sales for the products sold for each retailer, region, state, and city.
sales_total_rtailer_df = pd.pivot_table(sales_2020_2021_df, index=['retailer', 'region', 'state', 'city'], values=['total_sales'], aggfunc='sum', sort='descending')

# Optional: Rename the "total_sales" column to "Total Sales"
sales_total_rtailer_df = sales_total_rtailer_df.rename(columns={"total_sales":"Total Sales"})

# Show the top 5 results.
sales_total_rtailer_df.sort_values(by=['Total Sales'], ascending=False).head()
# Out:
#                                                     Total Sales
# retailer    region    state          city
# West Gear   West      California     San Francisco     32794405
# Kohl's      West      California     Los Angeles       25127160
# Foot Locker Northeast New York       New York          25008568
# West Gear   West      Washington     Seattle           24862675
# Foot Locker Southeast South Carolina Charleston        24822280

# %% [markdown]
# ### 5. Determine which Retailer Sold the Most Women's Athletic Footwear

# %%
# Filter the sales data to get the women's athletic footwear sales data.
# Create a DataFrame that filters the data on only womans athletic footware
womans_athletic_footware_df = sales_2020_2021_df.loc[sales_2020_2021_df['product']== "Women's Athletic Footwear"]
womans_athletic_footware_df.head(20)
# Out:
#         retailer  retailer_id invoice_date     region         state  \
# 21   Foot Locker      1185732   2020-01-04  Northeast      New York
# 22   Foot Locker      1185732   2020-01-04  Northeast      New York
# 23   Foot Locker      1185732   2020-01-04  Northeast      New York
# 26     West Gear      1128299   2020-01-05  Northeast  Pennsylvania
# 27     West Gear      1128299   2020-01-05  Northeast  Pennsylvania
# 29     West Gear      1128299   2020-01-05  Northeast  Pennsylvania
# 54     West Gear      1128299   2020-01-11       West        Nevada
# 55     West Gear      1128299   2020-01-11       West        Nevada
# 56     West Gear      1128299   2020-01-11       West        Nevada
# 72     West Gear      1128299   2020-01-17       West        Nevada
# 73     West Gear      1128299   2020-01-17       West        Nevada
# 74     West Gear      1128299   2020-01-17       West        Nevada
# 91   Foot Locker      1185732   2020-01-22  Northeast      New York
# ...

# %% [markdown]
# #### Using `groupby`

# %%
# Show the total number of women's athletic footwear sold for each retailer, region, state, and city.
womans_athletic_footware_products_sold_df = womans_athletic_footware_df.groupby(['retailer','region', 'state', 'city'])[['units_sold']].sum()
# Rename the "units_sold" column to "Womens_Footwear_Units_Sold"
womans_athletic_footware_products_sold_df = womans_athletic_footware_products_sold_df.rename(columns={"units_sold":"Womens_Footwear_Units_Sold"})
# Show the top 5 results.
womans_athletic_footware_products_sold_df.sort_values(by=["Womens_Footwear_Units_Sold"], ascending=False).head()
# Out:
#                                                       Womens_Footwear_Units_Sold
# retailer      region    state          city
# West Gear     West      California     San Francisco                       12107
# Foot Locker   Northeast New York       New York                            10996
# Kohl's        West      California     Los Angeles                         10826
# Foot Locker   Southeast South Carolina Charleston                           8814
# Sports Direct South     Texas          Dallas                               8790

# %% [markdown]
# #### Using `pivot_table`

# %%
# Show the total number of women's athletic footwear sold for each retailer, region, state, and city.
womans_product_total_df = pd.pivot_table(womans_athletic_footware_df, index=['retailer', 'region', 'state', 'city'], values=['units_sold'], aggfunc='sum', sort='descending')

# Rename the "units_sold" column to "Womens_Footwear_Units_Sold"
womans_product_total_df = womans_product_total_df.rename(columns={"units_sold":"Womens_Footwear_Units_Sold"})
# Show the top 5 results.
womans_product_total_df.sort_values(by=["Womens_Footwear_Units_Sold"], ascending=False).head()
# Out:
#                                                       Womens_Footwear_Units_Sold
# retailer      region    state          city
# West Gear     West      California     San Francisco                       12107
# Foot Locker   Northeast New York       New York                            10996
# Kohl's        West      California     Los Angeles                         10826
# Foot Locker   Southeast South Carolina Charleston                           8814
# Sports Direct South     Texas          Dallas                               8790

# %% [markdown]
# ### 5. Determine the Day with the Most Women's Athletic Footwear Sales

# %%
# Create a pivot table with the 'invoice_date' column is the index, and the "total_sales" as the values.
womans_top_day_df = pd.pivot_table(womans_athletic_footware_df, index=['invoice_date'], values=['total_sales'], aggfunc='sum', sort='descending')
# Optional: Rename the "total_sales" column to "Total Sales"
womans_top_day_df_rn = womans_top_day_df.rename(columns={"total_sales":"Total Sales"})

# Show the table.
womans_top_day_df_rn.sort_values(by=["Total Sales"], ascending=False).head()
# Out:
#               Total Sales
# invoice_date
# 2021-07-16        1521825
# 2021-12-16        1473497
# 2021-06-17        1376988
# 2021-08-17        1086294
# 2021-07-23        1021806

# %%
# Resample the pivot table into daily bins, and get the total sales for each day.
# create and empty dictionary for each day
monday_total = 0
tuesday_total = 0
wednesday_total = 0
thursday_total = 0
friday_total = 0
saturday_total = 0
sunday_total = 0
# cycle through each roe of the dataframe and check which day of the week it is
for womans_top_day_df['invoice_date'] in womans_top_day_df:
    if womans_top_day_df['invoice_date'].weekday() == 0:
        monday_total += womans_top_day_df['Total Sales']
    elif womans_top_day_df['invoice_date'].weekday() == 1:
        tuesday_total += womans_top_day_df['Total Sales']
    elif womans_top_day_df['invoice_date'].weekday() == 2:
        wednesday_total += womans_top_day_df['Total Sales']
    elif womans_top_day_df['invoice_date'].weekday() == 3:
        thursday_total += womans_top_day_df['Total Sales']
    elif womans_top_day_df['invoice_date'].weekday() == 4:
        friday_total += womans_top_day_df['Total Sales']
    elif womans_top_day_df['invoice_date'].weekday() == 5:
        saturday_total += womans_top_day_df['Total Sales']
    else:
        sunday_total += womans_top_day_df['Total Sales']
#make a new dataframe with the totals from the previous section

womans_total_df = pd.DataFrame({'Monday': monday_total, 'Tuesday': tuesday_total, 'Wednesday': wednesday_total, 'Thursday': thursday_total, 'Friday': friday_total, 'Saturday': saturday_total, 'Sunday': sunday_total})

# Sort the resampled pivot table in ascending order on "Total Sales".
womans_total_df.sort_values(by=["Total Sales"], ascending=False).head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_30752\1776262263.py in ?()
#       8 saturday_total = 0
#       9 sunday_total = 0
#      10 # cycle through each roe of the dataframe and check which day of the week it is
#      11 for womans_top_day_df['invoice_date'] in womans_top_day_df:
# ---> 12     if womans_top_day_df['invoice_date'].weekday() == 0:
#      13         monday_total += womans_top_day_df['Total Sales']
#      14     elif womans_top_day_df['invoice_date'].weekday() == 1:
#      15         tuesday_total += womans_top_day_df['Total Sales']
#
# c:\Users\matth\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6200             and name not in self._accessors
#    6201             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6202         ):
#    6203             return self[name]
# ...

# %% [markdown]
# ### 6.  Determine the Week with the Most Women's Athletic Footwear Sales

# %%
# Resample the womans_top_day_df table into weekly bins, and get the total sales for each week.
womans_weeks= []
week_number = 0
for row in womans_athletic_footware_df:
    for x in range(6):
        womans_weeks.append(f"Week ": week_number, "Total Sales" : {womans_athletic_footware_df['total_sales']})
    week_number += 1
womans_weeks_df = pd.DataFrame(womans_weeks)    
womans_weeks_df.sort_values(by=["Total Sales"], ascending=False).head()
### 7.  Determine the Month with the Most Women's Athletic Footwear Sales
womans_months= []
month_number = 0
for row in womans_weeks_df:
    for x in range(3):
        womans_weeks.append("Month ": month_number, "Total Sales" : {womans_athletic_footware_df['total_sales']})
    week_number += 1
womans_months_df = pd.DataFrame(womans_months)    

# Sort the resampled pivot table in ascending order on "Total Sales".
womans_months_df.sort_values(by=["Total Sales"], ascending=False).head()
